# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
import math
# %matplotlib inline

# %% [markdown]
# To visualize a dense neural network, we'll draw a graph in code.

# %%
dense = nx.Graph()
inputs = {i: (0, i) for i in range(0, 10)}
activations = {i+100: (1, i) for i in range(0, 10)}
outputs= {i+1000: (2, i) for i in range(0, 2)}
all = {**inputs, **activations, **outputs}
#and now -- fully connected
for input in inputs:
    for activation in activations:
        dense.add_edge(input, activation)
for activation in activations:
    for output in outputs:
        dense.add_edge(activation, output)
nx.draw_networkx_nodes(dense, all, nodelist=all.keys(), node_color='b')
nx.draw_networkx_edges(dense, all)
plt.axis('off')
pass

# %% [markdown]
# What makes a neural network able to learn interesting patterns is the concept of non-linearity. Very literally this means a function that does not generate a straight line.
#
# Very commonly two kinds of non linearity are used -- the relu, and the sigmoid. These non linear 'activation functions' will be used in the layers of our neural network.

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def relu(x):
    return np.maximum(x, 0)


x = np.arange(-5., 5., 0.2)
plt.subplot(121)
plt.title('sigmoid')
plt.plot(x, sigmoid(x))
plt.subplot(122)
plt.title('relu')
plt.plot(x, relu(x))
pass

# %% [markdown]
# And on output, our output classes work best when we can think of them as probabilities that all add up to 1. This way we can tell the best matching prediction made by our neural network.

# %%
def softmax(x):
    return np.exp(x) / np.sum(np.exp(x), axis=0)
sample_outputs = [1, 2, 5]
softmax(sample_outputs)
# Out:
# array([ 0.01714783,  0.04661262,  0.93623955])

# %%
softmax(sample_outputs).sum()
# Out:
# 1.0

# %% [markdown]
# Now with those concepts in mind, let's actually build a dense neural network to learn to recognize handwritten digits. Starting with the training and testing data.

# %%
import keras
from keras.datasets import mnist
from keras.layers import Input, Dense, Dropout, Flatten
from keras.models import Model
# Out:
# Using TensorFlow backend.

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train / np.max(x_train)
x_test = x_test / np.max(x_test)
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

# %% [markdown]
# And now, using the Keras functional API, stack together layers starting with the input, through Dense and Dropout learning layers, and then on to a final softmax output.
#
# Dropout is a device to help your network not memorize the input. The larger the number of parameters in your model, the larger the chance your model memorizes the input. Dropout is selective forgetting, turning off parts of the model randomly to avoid memorization.
#
# One thing to note here is Flatten. Because our images are two dimensional *x,y* pairs, and our output is one dimension -- a class 0-9, Flatten is needed to reduce the dimensions.

# %%
input_layer = Input(shape=x_train[0].shape)
dense_1 = Dense(32, activation='relu')(input_layer)
dropout_1 = Dropout(0.1)(dense_1)
dense_2 = Dense(32, activation='relu')(dropout_1)
dropout_2 = Dropout(0.1)(dense_2)
flat = Flatten()(dropout_2)
output_layer = Dense(10, activation='softmax')(flat)

model = Model(inputs=[input_layer], outputs=[output_layer])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 28, 28)            0
# _________________________________________________________________
# dense_169 (Dense)            (None, 28, 32)            928
# _________________________________________________________________
# dropout_113 (Dropout)        (None, 28, 32)            0
# _________________________________________________________________
# dense_170 (Dense)            (None, 28, 32)            1056
# _________________________________________________________________
# dropout_114 (Dropout)        (None, 28, 32)            0
# _________________________________________________________________
# flatten_57 (Flatten)         (None, 896)               0
# _________________________________________________________________
# dense_171 (Dense)            (None, 10)                8970
# =================================================================
# Total params: 10,954
# Trainable params: 10,954
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# With the model assembled, we compile it, which prepares the model for execution with a solver. The solver is a mathematical search engine, it works through the possible values of our trainable parameters. This seems like a lot of work -- and it is -- but multiple different solver algorithms exist which prevent the solver from looking at every possible number.
#
# The trick is the *loss* which is feedback to the solver as to whether it is getting better or worse. Picking the right loss function to work with your network is important, but can be approached as a cookbook.
#
# The loss functions are a bit hard to relate to, so we also have a metric. Accuracy is straightforward, telling you the percentage of the time you model predicted the right answer.

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=64,
                    epochs=8,
                    verbose=1,
                    validation_data=(x_test, y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/8
# 60000/60000 [==============================] - 8s - loss: 0.4188 - acc: 0.8781 - val_loss: 0.2068 - val_acc: 0.9381
# Epoch 2/8
# 60000/60000 [==============================] - 7s - loss: 0.2028 - acc: 0.9396 - val_loss: 0.1611 - val_acc: 0.9525
# Epoch 3/8
# 60000/60000 [==============================] - 7s - loss: 0.1718 - acc: 0.9484 - val_loss: 0.1381 - val_acc: 0.9591
# Epoch 4/8
# 60000/60000 [==============================] - 7s - loss: 0.1540 - acc: 0.9544 - val_loss: 0.1259 - val_acc: 0.9640
# Epoch 5/8
# 60000/60000 [==============================] - 7s - loss: 0.1415 - acc: 0.9569 - val_loss: 0.1222 - val_acc: 0.9640
# Epoch 6/8
# 60000/60000 [==============================] - 7s - loss: 0.1348 - acc: 0.9596 - val_loss: 0.1172 - val_acc: 0.9662
# Epoch 7/8
# 60000/60000 [==============================] - 7s - loss: 0.1263 - acc: 0.9622 - val_loss: 0.1112 - val_acc: 0.9668
# Epoch 8/8
# 60000/60000 [==============================] - 7s - loss: 0.1222 - acc: 0.9632 - val_loss: 0.1121 - val_acc: 0.9664

# %% [markdown]
# Parameters are numbers found by the solver, inside the model. Hyperparameters are numbers or settings we supply to create the model. Building a better model involves iteration and tuning these hyperparameters.
#
# Fortunately, we can use another layer of machine learning -- Grid Search -- to work through a set of hyperparameters for us. Grid search uses cross validation, splitting the training data up into folds for training and testing of each hyperparameter combination. After all hyperparameter variants are trained, the original test data is used to validate the final model.
#
#
# Machine learing often involves a lot of human waiting!

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import Sequential
import time

# %%
def dense_model(units, dropout):
    model = Sequential()
    model.add(Dense(units, activation='relu', input_shape=(28, 28,)))
    model.add(Dropout(dropout))
    model.add(Dense(units, activation='relu'))
    model.add(Dropout(dropout))
    model.add(Flatten())
    model.add(Dense(10, activation='softmax'))
    model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
    return model

hyperparameters = {
    'epochs': [1],
    'batch_size': [64],
    'units': [32, 64, 128],
    'dropout': [0.1, 0.2, 0.4]
}

model = KerasClassifier(build_fn=dense_model, verbose=0)
start = time.clock()
grid = GridSearchCV(estimator=model, param_grid=hyperparameters, cv=6, verbose=4)
grid_result = grid.fit(x_train, y_train)
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))

#the KerasClassifier comes back with the labels 0-9, so we use argmax
#to turn our one-hot encoding into 0-9 digit labels
y_true, y_pred = np.argmax(y_test, axis=1), grid.predict(x_test)
print()
print(classification_report(y_true, y_pred))
print()
print(time.clock() - start)
# Out:
# Fitting 6 folds for each of 9 candidates, totalling 54 fits
# [CV] batch_size=64, dropout=0.1, epochs=1, units=32 ..................
# [CV]  batch_size=64, dropout=0.1, epochs=1, units=32, score=0.937000, total=   6.2s
# [CV] batch_size=64, dropout=0.1, epochs=1, units=32 ..................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    7.6s remaining:    0.0s
# [CV]  batch_size=64, dropout=0.1, epochs=1, units=32, score=0.927500, total=   6.2s
# [CV] batch_size=64, dropout=0.1, epochs=1, units=32 ..................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   15.4s remaining:    0.0s
# [CV]  batch_size=64, dropout=0.1, epochs=1, units=32, score=0.928300, total=   6.5s
# [CV] batch_size=64, dropout=0.1, epochs=1, units=32 ..................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   23.3s remaining:    0.0s
# [CV]  batch_size=64, dropout=0.1, epochs=1, units=32, score=0.929100, total=   6.3s
# [CV] batch_size=64, dropout=0.1, epochs=1, units=32 ..................
# [CV]  batch_size=64, dropout=0.1, epochs=1, units=32, score=0.917100, total=   6.4s
# [CV] batch_size=64, dropout=0.1, epochs=1, units=32 ..................
# [CV]  batch_size=64, dropout=0.1, epochs=1, units=32, score=0.939000, total=   6.3s
# [CV] batch_size=64, dropout=0.1, epochs=1, units=64 ..................
# [CV]  batch_size=64, dropout=0.1, epochs=1, units=64, score=0.944400, total=   9.4s
# [CV] batch_size=64, dropout=0.1, epochs=1, units=64 ..................
# [CV]  batch_size=64, dropout=0.1, epochs=1, units=64, score=0.941600, total=   9.4s
# [CV] batch_size=64, dropout=0.1, epochs=1, units=64 ..................
# [CV]  batch_size=64, dropout=0.1, epochs=1, units=64, score=0.942800, total=   9.3s
# [CV] batch_size=64, dropout=0.1, epochs=1, units=64 ..................
# [CV]  batch_size=64, dropout=0.1, epochs=1, units=64, score=0.939200, total=   9.4s
# [CV] batch_size=64, dropout=0.1, epochs=1, units=64 ..................
# [CV]  batch_size=64, dropout=0.1, epochs=1, units=64, score=0.934900, total=   9.5s
# [CV] batch_size=64, dropout=0.1, epochs=1, units=64 ..................
# [CV]  batch_size=64, dropout=0.1, epochs=1, units=64, score=0.953400, total=   9.6s
# [CV] batch_size=64, dropout=0.1, epochs=1, units=128 .................
# [CV]  batch_size=64, dropout=0.1, epochs=1, units=128, score=0.950200, total=  16.7s
# [CV] batch_size=64, dropout=0.1, epochs=1, units=128 .................
# [CV]  batch_size=64, dropout=0.1, epochs=1, units=128, score=0.954900, total=  17.4s
# [CV] batch_size=64, dropout=0.1, epochs=1, units=128 .................
# [CV]  batch_size=64, dropout=0.1, epochs=1, units=128, score=0.951300, total=  16.5s
# [CV] batch_size=64, dropout=0.1, epochs=1, units=128 .................
# [CV]  batch_size=64, dropout=0.1, epochs=1, units=128, score=0.953700, total=  16.6s
# [CV] batch_size=64, dropout=0.1, epochs=1, units=128 .................
# [CV]  batch_size=64, dropout=0.1, epochs=1, units=128, score=0.947800, total=  16.7s
# [CV] batch_size=64, dropout=0.1, epochs=1, units=128 .................
# [CV]  batch_size=64, dropout=0.1, epochs=1, units=128, score=0.957600, total=  16.8s
# [CV] batch_size=64, dropout=0.2, epochs=1, units=32 ..................
# [CV]  batch_size=64, dropout=0.2, epochs=1, units=32, score=0.932700, total=   7.0s
# [CV] batch_size=64, dropout=0.2, epochs=1, units=32 ..................
# [CV]  batch_size=64, dropout=0.2, epochs=1, units=32, score=0.931000, total=   6.8s
# [CV] batch_size=64, dropout=0.2, epochs=1, units=32 ..................
# [CV]  batch_size=64, dropout=0.2, epochs=1, units=32, score=0.922400, total=   6.7s
# [CV] batch_size=64, dropout=0.2, epochs=1, units=32 ..................
# [CV]  batch_size=64, dropout=0.2, epochs=1, units=32, score=0.926500, total=   7.0s
# [CV] batch_size=64, dropout=0.2, epochs=1, units=32 ..................
# [CV]  batch_size=64, dropout=0.2, epochs=1, units=32, score=0.920000, total=   6.7s
# [CV] batch_size=64, dropout=0.2, epochs=1, units=32 ..................
# [CV]  batch_size=64, dropout=0.2, epochs=1, units=32, score=0.935600, total=   7.0s
# [CV] batch_size=64, dropout=0.2, epochs=1, units=64 ..................
# [CV]  batch_size=64, dropout=0.2, epochs=1, units=64, score=0.940700, total=  10.3s
# [CV] batch_size=64, dropout=0.2, epochs=1, units=64 ..................
# [CV]  batch_size=64, dropout=0.2, epochs=1, units=64, score=0.940800, total=   9.8s
# [CV] batch_size=64, dropout=0.2, epochs=1, units=64 ..................
# [CV]  batch_size=64, dropout=0.2, epochs=1, units=64, score=0.942700, total=  10.2s
# [CV] batch_size=64, dropout=0.2, epochs=1, units=64 ..................
# [CV]  batch_size=64, dropout=0.2, epochs=1, units=64, score=0.940400, total=  10.6s
# [CV] batch_size=64, dropout=0.2, epochs=1, units=64 ..................
# [CV]  batch_size=64, dropout=0.2, epochs=1, units=64, score=0.937900, total=  10.6s
# [CV] batch_size=64, dropout=0.2, epochs=1, units=64 ..................
# [CV]  batch_size=64, dropout=0.2, epochs=1, units=64, score=0.948600, total=  10.6s
# [CV] batch_size=64, dropout=0.2, epochs=1, units=128 .................
# [CV]  batch_size=64, dropout=0.2, epochs=1, units=128, score=0.952300, total=  17.5s
# [CV] batch_size=64, dropout=0.2, epochs=1, units=128 .................
# [CV]  batch_size=64, dropout=0.2, epochs=1, units=128, score=0.950800, total=  18.0s
# [CV] batch_size=64, dropout=0.2, epochs=1, units=128 .................
# [CV]  batch_size=64, dropout=0.2, epochs=1, units=128, score=0.949000, total=  18.2s
# [CV] batch_size=64, dropout=0.2, epochs=1, units=128 .................
# [CV]  batch_size=64, dropout=0.2, epochs=1, units=128, score=0.949700, total=  18.1s
# [CV] batch_size=64, dropout=0.2, epochs=1, units=128 .................
# [CV]  batch_size=64, dropout=0.2, epochs=1, units=128, score=0.948500, total=  18.6s
# [CV] batch_size=64, dropout=0.2, epochs=1, units=128 .................
# [CV]  batch_size=64, dropout=0.2, epochs=1, units=128, score=0.956600, total=  18.0s
# [CV] batch_size=64, dropout=0.4, epochs=1, units=32 ..................
# [CV]  batch_size=64, dropout=0.4, epochs=1, units=32, score=0.924200, total=   7.7s
# [CV] batch_size=64, dropout=0.4, epochs=1, units=32 ..................
# [CV]  batch_size=64, dropout=0.4, epochs=1, units=32, score=0.920500, total=   7.8s
# [CV] batch_size=64, dropout=0.4, epochs=1, units=32 ..................
# [CV]  batch_size=64, dropout=0.4, epochs=1, units=32, score=0.917400, total=   7.8s
# [CV] batch_size=64, dropout=0.4, epochs=1, units=32 ..................
# [CV]  batch_size=64, dropout=0.4, epochs=1, units=32, score=0.915400, total=   7.8s
# [CV] batch_size=64, dropout=0.4, epochs=1, units=32 ..................
# [CV]  batch_size=64, dropout=0.4, epochs=1, units=32, score=0.911700, total=   8.1s
# [CV] batch_size=64, dropout=0.4, epochs=1, units=32 ..................
# [CV]  batch_size=64, dropout=0.4, epochs=1, units=32, score=0.931300, total=   7.9s
# [CV] batch_size=64, dropout=0.4, epochs=1, units=64 ..................
# [CV]  batch_size=64, dropout=0.4, epochs=1, units=64, score=0.937000, total=  11.0s
# [CV] batch_size=64, dropout=0.4, epochs=1, units=64 ..................
# [CV]  batch_size=64, dropout=0.4, epochs=1, units=64, score=0.935800, total=  10.7s
# [CV] batch_size=64, dropout=0.4, epochs=1, units=64 ..................
# [CV]  batch_size=64, dropout=0.4, epochs=1, units=64, score=0.939600, total=  11.5s
# [CV] batch_size=64, dropout=0.4, epochs=1, units=64 ..................
# [CV]  batch_size=64, dropout=0.4, epochs=1, units=64, score=0.935000, total=  11.3s
# [CV] batch_size=64, dropout=0.4, epochs=1, units=64 ..................
# [CV]  batch_size=64, dropout=0.4, epochs=1, units=64, score=0.932400, total=  11.4s
# [CV] batch_size=64, dropout=0.4, epochs=1, units=64 ..................
# [CV]  batch_size=64, dropout=0.4, epochs=1, units=64, score=0.947100, total=  11.4s
# [CV] batch_size=64, dropout=0.4, epochs=1, units=128 .................
# [CV]  batch_size=64, dropout=0.4, epochs=1, units=128, score=0.947600, total=  18.8s
# [CV] batch_size=64, dropout=0.4, epochs=1, units=128 .................
# [CV]  batch_size=64, dropout=0.4, epochs=1, units=128, score=0.948100, total=  19.0s
# [CV] batch_size=64, dropout=0.4, epochs=1, units=128 .................
# [CV]  batch_size=64, dropout=0.4, epochs=1, units=128, score=0.946500, total=  19.2s
# [CV] batch_size=64, dropout=0.4, epochs=1, units=128 .................
# [CV]  batch_size=64, dropout=0.4, epochs=1, units=128, score=0.943500, total=  19.2s
# [CV] batch_size=64, dropout=0.4, epochs=1, units=128 .................
# [CV]  batch_size=64, dropout=0.4, epochs=1, units=128, score=0.941300, total=  21.4s
# [CV] batch_size=64, dropout=0.4, epochs=1, units=128 .................
# [CV]  batch_size=64, dropout=0.4, epochs=1, units=128, score=0.954200, total=  20.3s
# [Parallel(n_jobs=1)]: Done  54 out of  54 | elapsed: 13.2min finished
# Best: 0.952583 using {'batch_size': 64, 'dropout': 0.1, 'epochs': 1, 'units': 128}
#
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.98       980
#           1       0.98      0.99      0.98      1135
#           2       0.96      0.93      0.94      1032
#           3       0.91      0.96      0.94      1010
#           4       0.97      0.96      0.97       982
#           5       0.98      0.91      0.94       892
#           6       0.95      0.98      0.97       958
#           7       0.94      0.96      0.95      1028
#           8       0.96      0.94      0.95       974
#           9       0.95      0.93      0.94      1009
#
# avg / total       0.96      0.96      0.96     10000
#
#
# 1218.651359
